# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").appName("WordCount").getOrCreate()
print("SparkSession foi criado")
# Out:
# SparkSession foi criado

# %%
# !wget --header="Authorization: token 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" \https://raw.githubusercontent.com/leiderosario/PB-LEIDE-ROSARIO/refs/heads/main/README.MD?token=GHSAT0AAAAAAC3LHBRYUB6EXFTWLM3R6DOCZ3PHBWA -O README.md
# Out:
# --2024-12-27 23:32:23--  https://raw.githubusercontent.com/leiderosario/PB-LEIDE-ROSARIO/refs/heads/main/README.MD?token=GHSAT0AAAAAAC3LHBRYUB6EXFTWLM3R6DOCZ3PHBWA
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2346 (2.3K) [text/plain]
# Saving to: ‘README.md’
#
# README.md           100%[===================>]   2.29K  --.-KB/s    in 0s
#
# 2024-12-27 23:32:24 (32.6 MB/s) - ‘README.md’ saved [2346/2346]

# %%
# !ls -l README.md
# Out:
# -rw-r--r-- 1 root root 2346 Dec 27 23:32 README.md

# %%
rdd = spark.sparkContext.textFile("README.md")

# %%
words = rdd.flatMap(lambda line: line.split())
word_counts = words.map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
for word, count in word_counts.collect():
 print(f"{word}: {count}")
# Out:
# #: 1
# chamo: 1
# Rosário: 1
# estudante: 1
# licenciatura: 1
# em: 12
# acredito: 1
# profundamente: 1
# no: 6
# poder: 1
# da: 2
# objetivo: 1
# desenvolver: 1
# mundo: 1
# contribuir: 1
# cada: 1
# vez: 1
# pessoas: 1
# meio: 2
# das: 2
# soluções: 1
# que: 4
# juntos!: 1
# |: 4
# Localização:: 1
# 🏫: 1
# Instituição: 1
# ensino:: 1
# Universidade: 1
# do: 4
# Computação: 1
# 📅: 1
# Semestre: 1
# atual:: 1
# Primeiro: 1
# Como: 2
# atividade: 1
# participar: 1
# uma: 2
# médio,: 1
# desenvolvi: 1
# projetos: 1
# para: 4
# ensino: 1
# técnicas: 2
# como: 3
# gamificação,: 1
# jogos: 1
# educativos: 1
# tornar: 1
# práticas: 2
# os: 1
# participarem: 1
# ativamente.: 1
# Essas: 1
# proporcionaram: 1
# experiência: 2
# interativa,: 1
# desenvolvimento: 1
# estudantes: 1
# maneira: 2
# estou: 2
# programa: 1
# bolsas: 1
# Compass: 1
# onde: 1
# obtendo: 1
# farão: 1
# toda: 1
# diferença: 1
# vida: 1
# acadêmica: 1
# profissional.: 1
# possuo: 1
# há: 1
# 12: 1
# liderança: 1
# ...

# %%
output_file = "palavras_contadas.txt"

# Abrir o arquivo no modo de escrita
with open(output_file, "w") as f:
    for word, count in word_counts.collect():  # Certifique-se de que word_counts já está definido.
        f.write(f"{word}: {count}\n")  # Escrever cada palavra e sua contagem no arquivo.

# Fazer o download do arquivo no Google Colab
from google.colab import files
files.download(output_file)
